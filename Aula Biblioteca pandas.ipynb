# %%
import pandas as pd

# %%
#carregar os dados de credito para um dataframe
dados = pd.read_csv("credit.csv")
dados.shape
# Out:
# (1000, 21)

# %%
dados.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
dados.tail(2)
# Out:
#     checking_status  duration                    credit_history     purpose  \
# 998              <0        45                   'existing paid'    radio/tv
# 999        0<=X<200        45  'critical/other existing credit'  'used car'
#
#      credit_amount savings_status  employment  installment_commitment  \
# 998           1845           <100      1<=X<4                       4
# 999           4576     100<=X<500  unemployed                       3
#
#     personal_status other_parties  ...   property_magnitude age  \
# 998   'male single'          none  ...  'no known property'  23
# 999   'male single'          none  ...                  car  27
#
#      other_payment_plans     housing existing_credits      job num_dependents  \
# 998                 none  'for free'                1  skilled              1
# 999                 none         own                1  skilled              1
#
#      own_telephone foreign_worker class
# 998            yes            yes   bad
# ...

# %%
dados[["duration"]]
# Out:
#      duration
# 0           6
# 1          48
# 2          12
# 3          42
# 4          24
# ..        ...
# 995        12
# 996        30
# 997        12
# 998        45
# 999        45
#
# [1000 rows x 1 columns]

# %%
dados.loc[2:4]
# Out:
#   checking_status  duration                    credit_history  \
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount savings_status employment  \
# 2            education           2096           <100     4<=X<7
# 3  furniture/equipment           7882           <100     4<=X<7
# 4            'new car'           4870           <100     1<=X<4
#
#    installment_commitment personal_status other_parties  ...  \
# 2                       2   'male single'          none  ...
# 3                       2   'male single'     guarantor  ...
# 4                       3   'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 2        'real estate'  49                 none         own                1
# ...

# %%
dados.loc[[5,9]]
# Out:
#   checking_status  duration                    credit_history    purpose  \
# 5   'no checking'        36                   'existing paid'  education
# 9        0<=X<200        30  'critical/other existing credit'  'new car'
#
#    credit_amount      savings_status  employment  installment_commitment  \
# 5           9055  'no known savings'      1<=X<4                       2
# 9           5234                <100  unemployed                       4
#
#   personal_status other_parties  ...   property_magnitude age  \
# 5   'male single'          none  ...  'no known property'  35
# 9  'male mar/wid'          none  ...                  car  28
#
#    other_payment_plans     housing existing_credits  \
# 5                 none  'for free'                1
# 9                 none         own                2
#
#                            job num_dependents  own_telephone foreign_worker  \
# 5         'unskilled resident'              2            yes            yes
# ...

# %%
dados.loc[dados['purpose'] == "radio/tv"]
# Out:
#     checking_status  duration                    credit_history   purpose  \
# 0                <0         6  'critical/other existing credit'  radio/tv
# 1          0<=X<200        48                   'existing paid'  radio/tv
# 8     'no checking'        12                   'existing paid'  radio/tv
# 12         0<=X<200        12                   'existing paid'  radio/tv
# 15               <0        24                   'existing paid'  radio/tv
# ..              ...       ...                               ...       ...
# 989        0<=X<200        24  'critical/other existing credit'  radio/tv
# 991   'no checking'        15                        'all paid'  radio/tv
# 992              <0        18                   'existing paid'  radio/tv
# 997   'no checking'        12                   'existing paid'  radio/tv
# 998              <0        45                   'existing paid'  radio/tv
#
#      credit_amount      savings_status employment  installment_commitment  \
# ...

# %%
dados.loc[dados['credit_amount'] > 12000]
# Out:
#     checking_status  duration                    credit_history  \
# 18         0<=X<200        24                   'existing paid'
# 63         0<=X<200        48             'no credits/all paid'
# 87         0<=X<200        36                   'existing paid'
# 95         0<=X<200        54             'no credits/all paid'
# 236        0<=X<200         6                   'existing paid'
# 272        0<=X<200        48                        'all paid'
# 373   'no checking'        60  'critical/other existing credit'
# 374        0<=X<200        60                        'all paid'
# 378        0<=X<200        36                   'existing paid'
# 381        0<=X<200        18                   'existing paid'
# 563        0<=X<200        36                   'existing paid'
# 615        0<=X<200        48             'no credits/all paid'
# 637   'no checking'        60              'delayed previously'
# 714        0<=X<200        60                   'existing paid'
# ...

# %%
dados2 = dados.loc[dados['credit_amount'] > 14000]
print(dados2)
# Out:
#     checking_status  duration                    credit_history  \
# 63         0<=X<200        48             'no credits/all paid'
# 95         0<=X<200        54             'no credits/all paid'
# 236        0<=X<200         6                   'existing paid'
# 374        0<=X<200        60                        'all paid'
# 378        0<=X<200        36                   'existing paid'
# 637   'no checking'        60              'delayed previously'
# 714        0<=X<200        60                   'existing paid'
# 744              <0        39  'critical/other existing credit'
# 818              <0        36                   'existing paid'
# 887        0<=X<200        48                   'existing paid'
# 915        0<=X<200        48             'no credits/all paid'
# 917              <0         6                   'existing paid'
#
#                  purpose  credit_amount      savings_status  employment  \
# ...

# %%
serie1 = pd.Series([2,4,5,6,7,8,6,4])
print(serie1)
# Out:
# 0    2
# 1    4
# 2    5
# 3    6
# 4    7
# 5    8
# 6    6
# 7    4
# dtype: int64

# %%
serie2 = dados['purpose']
print (serie2)
type(serie2)
# Out:
# 0                 radio/tv
# 1                 radio/tv
# 2                education
# 3      furniture/equipment
# 4                'new car'
#               ...
# 995    furniture/equipment
# 996             'used car'
# 997               radio/tv
# 998               radio/tv
# 999             'used car'
# Name: purpose, Length: 1000, dtype: object
# pandas.core.series.Series

# %%
dados.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
dados.rename(columns={"duration":"duração","purpose":"proposito"})
# Out:
#     checking_status  duração                    credit_history  \
# 0                <0        6  'critical/other existing credit'
# 1          0<=X<200       48                   'existing paid'
# 2     'no checking'       12  'critical/other existing credit'
# 3                <0       42                   'existing paid'
# 4                <0       24              'delayed previously'
# ..              ...      ...                               ...
# 995   'no checking'       12                   'existing paid'
# 996              <0       30                   'existing paid'
# 997   'no checking'       12                   'existing paid'
# 998              <0       45                   'existing paid'
# 999        0<=X<200       45  'critical/other existing credit'
#
#                proposito  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
dados.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
dados.rename(columns={"duration":"duração","purpose":"proposito"},inplace=True)

# %%
dados.head(2)
# Out:
#   checking_status  duração                    credit_history proposito  \
# 0              <0        6  'critical/other existing credit'  radio/tv
# 1        0<=X<200       48                   'existing paid'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
# 1           5951                <100     1<=X<4                       2
#
#         personal_status other_parties  ...  property_magnitude age  \
# 0         'male single'          none  ...       'real estate'  67
# 1  'female div/dep/mar'          none  ...       'real estate'  22
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
# 1                 none     own                1  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
# ...

# %%
dados.drop('checking_status',axis=1,inplace=True)

# %%
dados.head(2)
# Out:
#    duração                    credit_history proposito  credit_amount  \
# 0        6  'critical/other existing credit'  radio/tv           1169
# 1       48                   'existing paid'  radio/tv           5951
#
#        savings_status employment  installment_commitment  \
# 0  'no known savings'        >=7                       4
# 1                <100     1<=X<4                       2
#
#         personal_status other_parties  residence_since property_magnitude  \
# 0         'male single'          none                4      'real estate'
# 1  'female div/dep/mar'          none                2      'real estate'
#
#    age other_payment_plans housing  existing_credits      job  num_dependents  \
# 0   67                none     own                 2  skilled               1
# 1   22                none     own                 1  skilled               1
#
#   own_telephone foreign_worker class
# 0           yes            yes  good
# 1          none            yes   bad

# %%
dados.isnull()
# Out:
#      duração  credit_history  proposito  credit_amount  savings_status  \
# 0      False           False      False          False           False
# 1      False           False      False          False           False
# 2      False           False      False          False           False
# 3      False           False      False          False           False
# 4      False           False      False          False           False
# ..       ...             ...        ...            ...             ...
# 995    False           False      False          False           False
# 996    False           False      False          False           False
# 997    False           False      False          False           False
# 998    False           False      False          False           False
# 999    False           False      False          False           False
#
#      employment  installment_commitment  personal_status  other_parties  \
# ...

# %%
dados.isnull().sum()
# Out:
# duração                   0
# credit_history            0
# proposito                 0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
dados.dropna()
# Out:
#      duração                    credit_history            proposito  \
# 0          6  'critical/other existing credit'             radio/tv
# 1         48                   'existing paid'             radio/tv
# 2         12  'critical/other existing credit'            education
# 3         42                   'existing paid'  furniture/equipment
# 4         24              'delayed previously'            'new car'
# ..       ...                               ...                  ...
# 995       12                   'existing paid'  furniture/equipment
# 996       30                   'existing paid'           'used car'
# 997       12                   'existing paid'             radio/tv
# 998       45                   'existing paid'             radio/tv
# 999       45  'critical/other existing credit'           'used car'
#
#      credit_amount      savings_status  employment  installment_commitment  \
# ...
