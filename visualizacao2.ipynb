# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import seaborn as sns

# %%
base=pd.read_csv('insect.csv')
base.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
agrupado = base.groupby(['spray'])['count'].sum()
agrupado
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
agrupado.plot.bar(color = 'blue')
# Out:
# <AxesSubplot: xlabel='spray'>

# %%
agrupado.plot.bar(color = ['blue','green','cyan','red'])
# Out:
# <AxesSubplot: xlabel='spray'>

# %%
agrupado.plot.pie(legend=True)
# Out:
# <AxesSubplot: ylabel='count'>

# %%
sns.boxplot(data=base.spray).set_title('Spray')
# Out:
# Text(0.5, 1.0, 'Spray')

# %%
df = pd.read_csv('chicken.csv')
df.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
agrupado2 = df.groupby(['feed'])['weight'].sum()
agrupado2
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
agrupado2.plot.pie(legend=True)
# Out:
# <AxesSubplot: ylabel='weight'>

# %%
agrupado2.plot.bar(legend=True)
# Out:
# <AxesSubplot: xlabel='feed'>

# %%
#histograma de densidade
sns.kdeplot(df.loc[df['feed'] == 'casein'].weight).set(title = 'casein')
# Out:
# [Text(0.5, 1.0, 'casein')]

# %%
sns.histplot(df.loc[df['feed'] == 'casein'].weight, kde=True).set(title = 'casein')
# Out:
# [Text(0.5, 1.0, 'casein')]

# %%
plt.figure()
plt.subplot(3,2,1)
sns.histplot(df.loc[df['feed'] == 'horsebean'].weight, kde=True).set(title = 'horsebean')
plt.subplot(3,2,1)
sns.histplot(df.loc[df['feed'] == 'casein'].weight, kde=True).set(title = 'casein')
plt.subplot(3,2,1)
sns.histplot(df.loc[df['feed'] == 'linseed'].weight, kde=True).set(title = 'linseed')
plt.subplot(3,2,1)
sns.histplot(df.loc[df['feed'] == 'meatmeal'].weight, kde=True).set(title = 'meatmeal')
plt.subplot(3,2,1)
sns.histplot(df.loc[df['feed'] == 'soybean'].weight, kde=True).set(title = 'soybean')
plt.subplot(3,2,1)
sns.histplot(df.loc[df['feed'] == 'sunflower'].weight, kde=True).set(title = 'sunflower')
plt.tight_layout()
